# %% [markdown]
# # Data Scientist Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
#
# This notebook walks you through one of the most popular Udacity projects across machine learning and artificial intellegence nanodegree programs.  The goal is to classify images of dogs according to their breed.
#
# If you are looking for a more guided capstone project related to deep learning and convolutional neural networks, this might be just it.  Notice that even if you follow the notebook to creating your classifier, you must still create a blog post or deploy an application to fulfill the requirements of the capstone project.
#
# Also notice, you may be able to use only parts of this notebook (for example certain coding portions or the data) without completing all parts and still meet all requirements of the capstone project.
#
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](../images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
import random
import warnings
from glob import glob

import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from PIL import ImageFile
from sklearn.datasets import load_files
from tqdm import tqdm

from extract_bottleneck_features import *

warnings.filterwarnings('ignore')


random.seed(8675309)

# %%
# Define function to load train, test, and validation datasets
def load_dataset(path):
    """
    Load and process the dataset from the specified directory.

    Args:
        path (str): The path to the dataset directory.

    Returns:
        dog_files (list): A list of file paths for each image in the dataset.
        dog_targets (numpy.ndarray): One-hot encoded labels for each image, 
                                     representing 133 possible categories.
    """
    data = load_files(path)
    dog_files = data['filenames']
    dog_targets = tf.keras.utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# %%
# Load train, test, and validation datasets
train_files, train_targets = load_dataset('../data/dog_images/train')
valid_files, valid_targets = load_dataset('../data/dog_images/valid')
test_files, test_targets = load_dataset('../data/dog_images/test')

# Load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("../data/dog_images/train/*/"))]

# Print statistics about the dataset
print(f'There are {len(dog_names)} total dog categories.')
print(f'There are {len(train_files) + len(valid_files) + len(test_files)} total dog images.')
print(f'There are {len(train_files)} training dog images.')
print(f'There are {len(valid_files)} validation dog images.')
print(f'There are {len(test_files)} test dog images.')
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
# Load filenames in shuffled human dataset
human_files = np.array(glob("../data/lfw/*/*"))
random.shuffle(human_files)

# Print statistics about the human dataset
print(f'There are {len(human_files)} total human images.')
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier(
    '../data/haarcascades/haarcascade_frontalface_alt.xml'
    )

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    """
    Detect if a human face is present in the given image.

    Args:
        img_path (str): The file path to the image.

    Returns:
        bool: True if one or more faces are detected, False otherwise.
    """
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

def get_percentage_face_detector(files, name):
    """
    Calculate and print the percentage of images containing a human face.

    Args:
        files (list): A list of file paths to the images.
        name (str): A label indicating the name of files being evaluated.

    Returns:
        None
    """
    count = 0
    for image in tqdm(files):
        if face_detector(image):
            count += 1
    print(f'-> {count}% images of the first {len(files)} {name} files were'
          f' detected as human face.')


get_percentage_face_detector(human_files_short, 'human_files_short')
get_percentage_face_detector(dog_files_short, 'dog_files_short')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 157.09it/s]
# -> 100% images of the first 100 human_files_short files were detected as human face.
# 100%|██████████| 100/100 [00:02<00:00, 41.88it/s]
# -> 12% images of the first 100 dog_files_short files were detected as human face.

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# --*
# __Answer:__
#
# _In my opinion, requiring users to provide an image with a clearly visible face is reasonable to some extent, given the algorithm we currently use. This algorithm has both advantages and disadvantages that can be communicated to users. On the positive side, it’s relatively simple, easy to implement, computationally inexpensive, and yields optimal results in many cases. However, there are limitations—it may not work 100% of the time, especially in situations where the face is obscured or partially visible._
#
# _As an alternative to overcome this limitation, we could consider using more robust algorithms, such as Convolutional Neural Networks (CNNs). These models have the potential to detect human faces even in more complex scenarios, as they can be trained on a wide range of features and situations, making them more resilient and accurate at face detection across different conditions. While more computationally expensive, this approach could significantly improve the detection rate in cases where faces are not perfectly presented._
#
# *--
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
# define ResNet50 model
ResNet50_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb\_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb\_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
def path_to_tensor(img_path):
    """
    Convert an image file into a normalized 4D tensor.

    This function loads an image from the given file path, resizes it to the 
    target size of (224, 224), converts the image to a tensor format, and 
    normalizes it. The resulting tensor is expanded into a 4D array (batch size, 
    height, width, channels). If the image file is corrupted or unreadable, a 
    warning message is printed, and None is returned.

    Args:
        img_path (str): The file path to the image.

    Returns:
        np.ndarray or None: The 4D tensor representing the image, or None if the 
        image is corrupted or unreadable.
    """
    try:
        img = tf.keras.preprocessing.image.load_img(img_path, 
                                                    target_size=(224, 224))
        x = tf.keras.preprocessing.image.img_to_array(img)
        # Normalize the image tensor
        return np.expand_dims(x, axis=0)
    except IOError:
        print(f"Warning: Skipping corrupted image {img_path}")
        return None
    
def paths_to_tensor(img_paths):
    """
    Convert a list of image file paths into a 4D tensor.

    This function takes a list of image paths, converts each image into a tensor 
    using `path_to_tensor`, and appends it to a batch of tensors. If an image 
    is corrupted or unreadable, it is skipped. The final output is a 4D tensor 
    containing all the image tensors in the batch.

    Args:
        img_paths (list): A list of file paths to the images.

    Returns:
        np.ndarray: A 4D array containing all the image tensors in the batch.
    """
    batch_tensors = []
    for img_path in img_paths:
        tensor = path_to_tensor(img_path)
        if tensor is not None:
            batch_tensors.append(tensor[0])
    return np.array(batch_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
def ResNet50_predict_labels(img_path):
    """
    Predict the label of an image using the pre-trained ResNet50 model.

    This function processes an image located at `img_path` using ResNet50's 
    preprocessing function, converts it to a tensor, and returns the predicted 
    label as the index of the highest value in the prediction vector.

    Args:
        img_path (str): The file path to the image.

    Returns:
        int: The index of the predicted label.
    """
    img = tf.keras.applications.resnet50.preprocess_input(
            path_to_tensor(img_path)
        )
    return np.argmax(ResNet50_model.predict(img, verbose=0))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    """
    Determine whether a dog is detected in an image.

    This function uses the ResNet50 model to predict labels for the image. 
    If the prediction falls within the range of dog breed labels (151 to 268), 
    the function returns True, indicating a dog has been detected. Otherwise, 
    it returns False.

    Args:
        img_path (str): The file path to the image.

    Returns:
        bool: True if a dog is detected, False otherwise.
    """
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

def get_percentage_dog_detector(files, name):
    """
    Calculate and print the percentage of images containing a dog face.

    Args:
        files (list): A list of file paths to the images.
        name (str): A label indicating the name of files being evaluated.

    Returns:
        None
    """
    count = 0
    for image in tqdm(files):
        if dog_detector(image):
            count += 1
    print(f'-> {count}% images of the first {len(files)} {name} files were'
          f' detected as dog.')


get_percentage_dog_detector(human_files_short, 'human_files_short')
get_percentage_dog_detector(dog_files_short, 'dog_files_short')
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 12.26it/s]
# -> 0% images of the first 100 human_files_short files were detected as dog.
# 100%|██████████| 100/100 [00:07<00:00, 13.33it/s]
# -> 100% images of the first 100 dog_files_short files were detected as dog.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# | Brittany | Welsh Springer Spaniel |
# |- | - |
# |<img src="../images/Brittany_02625.jpg" width="100"> | <img src="../images/Welsh_springer_spaniel_08203.jpg" width="200"> |
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# |Curly-Coated Retriever | American Water Spaniel|
# |- | - |
# |<img src="../images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="../images/American_water_spaniel_00648.jpg" width="200">|
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# |Yellow Labrador | Chocolate Labrador | Black Labrador|
# |- | - | - |
# |<img src="../images/Labrador_retriever_06457.jpg" width="150"> | <img src="../images/Labrador_retriever_06455.jpg" width="240"> | <img src="../images/Labrador_retriever_06449.jpg" width="220">|
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
# Allow loading of truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True


def image_generator(files, targets, batch_size):
    """
    Generator function to yield batches of image data and their corresponding
    labels.

    This function randomly selects a batch of file paths, converts the images
    to tensors, and yields the batch of images along with their corresponding
    labels. It runs in an infinite loop, useful for training models in Keras.

    Args:
        files (np.ndarray): Array of file paths to the images.
        targets (np.ndarray): Array of corresponding labels for the images.
        batch_size (int): The size of each batch of images and labels.

    Yields:
        tuple: A tuple containing:
            - np.ndarray: Batch of image tensors.
            - np.ndarray: Batch of corresponding labels.
    """
    while True:
        batch_paths = np.random.choice(a=files, size=batch_size)
        batch_input = paths_to_tensor(batch_paths)
        valid_paths = [p for p in batch_paths if path_to_tensor(p) is not None]
        batch_indices = [
            np.where(files == img_path)[0][0] for img_path in valid_paths
        ]
        batch_output = np.array([targets[index] for index in batch_indices])

        if len(batch_input) > 0:  # Ensure there is data to yield
            yield batch_input, batch_output


# Create generators for train, validation, and test datasets
train_generator = image_generator(train_files, train_targets, batch_size=64)
valid_generator = image_generator(valid_files, valid_targets, batch_size=64)
test_generator = image_generator(test_files, test_targets, batch_size=64)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](../images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
### TODO: Define your architecture.
# building a linear stack of layers with the sequential model

input_shape = (224, 224, 3)
model = tf.keras.models.Sequential()

model.add(tf.keras.Input(shape=input_shape))

# Add the input layer and hidden layer 1
model.add(
    tf.keras.layers.Conv2D(
        16,
        kernel_size=(3, 3),
        activation="relu",
    )
)

# Add the input layer and hidden layer 2
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation="relu"))

# Flatten convolutional output
model.add(tf.keras.layers.Flatten())

# Add the input layer and hidden layer 3
model.add(tf.keras.layers.Dense(32, activation="relu"))

# Add the output layer
model.add(tf.keras.layers.Dense(133, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 220, 220, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1548800)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │    49,561,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 133)            │         4,389 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,571,109 (189.10 MB)
#  Trainable params: 49,571,109 (189.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the Model

# %%
# Set a smaller learning rate
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer=adam, loss="categorical_crossentropy", metrics=["accuracy"]
)

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: specify the number of epochs that you would like to use
#  to train the model.

epochs = 5

### Do NOT modify the code below this line.

# Add checkpoint to save the best model
checkpoint_cnn_filepath = "../saved_models/checkpoint.model.cnn.keras"
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_cnn_filepath, verbose=1, save_best_only=True
)

# ReduceLROnPlateau: This callback reduces the learning rate when a metric 
# has stopped improving.
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.1, patience=5
)

# Train the model
model.fit(
    train_generator,
    steps_per_epoch=len(train_files) // 32,
    validation_data=valid_generator,
    validation_steps=len(valid_files) // 32,
    epochs=epochs,
    callbacks=[checkpointer, reduce_lr],
    verbose=1,
)
# Out:
# Epoch 1/5
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.0076 - loss: 333.6201
# Epoch 1: val_loss improved from inf to 4.88485, saving model to ../saved_models/checkpoint.model.cnn.keras
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 153s 731ms/step - accuracy: 0.0076 - loss: 332.3930 - val_accuracy: 0.0072 - val_loss: 4.8849 - learning_rate: 0.0010
# Epoch 2/5
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.0103 - loss: 4.8818
# Epoch 2: val_loss improved from 4.88485 to 4.87850, saving model to ../saved_models/checkpoint.model.cnn.keras
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 150s 723ms/step - accuracy: 0.0103 - loss: 4.8818 - val_accuracy: 0.0090 - val_loss: 4.8785 - learning_rate: 0.0010
# Epoch 3/5
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - accuracy: 0.0095 - loss: 4.8771
# Epoch 3: val_loss improved from 4.87850 to 4.87405, saving model to ../saved_models/checkpoint.model.cnn.keras
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 152s 731ms/step - accuracy: 0.0095 - loss: 4.8771 - val_accuracy: 0.0096 - val_loss: 4.8741 - learning_rate: 0.0010
# Epoch 4/5
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.0094 - loss: 4.8751
# Epoch 4: val_loss did not improve from 4.87405
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 153s 736ms/step - accuracy: 0.0094 - loss: 4.8751 - val_accuracy: 0.0078 - val_loss: 4.8758 - learning_rate: 0.0010
# Epoch 5/5
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.0113 - loss: 4.8695
# Epoch 5: val_loss improved from 4.87405 to 4.86857, saving model to ../saved_models/checkpoint.model.cnn.keras
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 154s 739ms/step - accuracy: 0.0113 - loss: 4.8695 - val_accuracy: 0.0156 - val_loss: 4.8686 - learning_rate: 0.0010

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights(checkpoint_cnn_filepath)

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# Evaluate the model on the test data using `evaluate_generator`
test_loss, test_accuracy = model.evaluate(
    test_generator, steps=len(test_files) // 32
)

# Convert the accuracy to percentage
test_accuracy = test_accuracy * 100

print("Test accuracy: %.4f%%" % test_accuracy)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 298ms/step - accuracy: 0.0165 - loss: 4.8644
# Test accuracy: 1.3221%

# %% [markdown]
# #### Results
#
# | Model | Test accuracy |
# | -|-|
# | CNN |1.3221%|

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features_VGG16 = np.load('../data/bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features_VGG16['train']
valid_VGG16 = bottleneck_features_VGG16['valid']
test_VGG16 = bottleneck_features_VGG16['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = tf.keras.models.Sequential()
VGG16_model.add(
    tf.keras.layers.GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:])
)
VGG16_model.add(tf.keras.layers.Dense(133, activation="softmax"))

VGG16_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 133)            │        68,229 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,229 (266.52 KB)
#  Trainable params: 68,229 (266.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(
    loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"]
)

# %% [markdown]
# ### Train the Model

# %%
checkpoint_VGG16_filepath = "../saved_models/checkpoint.model.VGG16.keras"
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_VGG16_filepath, verbose=1, save_best_only=True
)

VGG16_model.fit(
    train_VGG16,
    train_targets,
    validation_data=(valid_VGG16, valid_targets),
    epochs=20,
    batch_size=20,
    callbacks=[checkpointer],
    verbose=1,
)
# Out:
# Epoch 1/20
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.1131 - loss: 11.9711
# Epoch 1: val_loss improved from inf to 3.58979, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1135 - loss: 11.9580 - val_accuracy: 0.4204 - val_loss: 3.5898
# Epoch 2/20
# 323/334 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.5790 - loss: 2.2902
# Epoch 2: val_loss improved from 3.58979 to 2.57188, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5800 - loss: 2.2856 - val_accuracy: 0.5772 - val_loss: 2.5719
# Epoch 3/20
# 297/334 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.7470 - loss: 1.1804
# Epoch 3: val_loss improved from 2.57188 to 1.99999, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.7468 - loss: 1.1860 - val_accuracy: 0.6467 - val_loss: 2.0000
# Epoch 4/20
# 282/334 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.8195 - loss: 0.7677
# Epoch 4: val_loss did not improve from 1.99999
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8187 - loss: 0.7748 - val_accuracy: 0.6635 - val_loss: 2.2210
# Epoch 5/20
# 295/334 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.8694 - loss: 0.5066
# Epoch 5: val_loss did not improve from 1.99999
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.8680 - loss: 0.5144 - val_accuracy: 0.6778 - val_loss: 2.0044
# Epoch 6/20
# 320/334 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.8972 - loss: 0.3719
# Epoch 6: val_loss improved from 1.99999 to 1.91953, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8969 - loss: 0.3739 - val_accuracy: 0.6802 - val_loss: 1.9195
# Epoch 7/20
# 293/334 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.9215 - loss: 0.2683
# Epoch 7: val_loss improved from 1.91953 to 1.81569, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9214 - loss: 0.2713 - val_accuracy: 0.7018 - val_loss: 1.8157
# Epoch 8/20
# 282/334 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.9398 - loss: 0.1937
# Epoch 8: val_loss did not improve from 1.81569
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9397 - loss: 0.1975 - val_accuracy: 0.7090 - val_loss: 1.8907
# Epoch 9/20
# 317/334 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.9530 - loss: 0.1711
# Epoch 9: val_loss did not improve from 1.81569
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9530 - loss: 0.1713 - val_accuracy: 0.7102 - val_loss: 1.8530
# Epoch 10/20
# 289/334 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.9646 - loss: 0.1209
# Epoch 10: val_loss improved from 1.81569 to 1.80979, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9639 - loss: 0.1233 - val_accuracy: 0.7281 - val_loss: 1.8098
# Epoch 11/20
# 294/334 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.9719 - loss: 0.0924
# Epoch 11: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.9717 - loss: 0.0932 - val_accuracy: 0.7066 - val_loss: 1.8984
# Epoch 12/20
# 300/334 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9762 - loss: 0.0821
# Epoch 12: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9760 - loss: 0.0825 - val_accuracy: 0.7234 - val_loss: 1.9490
# Epoch 13/20
# 298/334 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.9843 - loss: 0.0574
# Epoch 13: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9840 - loss: 0.0582 - val_accuracy: 0.7329 - val_loss: 1.8477
# Epoch 14/20
# 296/334 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.9886 - loss: 0.0320
# Epoch 14: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9881 - loss: 0.0340 - val_accuracy: 0.7401 - val_loss: 1.8104
# Epoch 15/20
# 298/334 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.9910 - loss: 0.0350
# Epoch 15: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9907 - loss: 0.0353 - val_accuracy: 0.7222 - val_loss: 1.9400
# Epoch 16/20
# 323/334 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9937 - loss: 0.0215
# Epoch 16: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9936 - loss: 0.0218 - val_accuracy: 0.7425 - val_loss: 1.8646
# Epoch 17/20
# 290/334 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.9941 - loss: 0.0181
# Epoch 17: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9941 - loss: 0.0185 - val_accuracy: 0.7557 - val_loss: 1.9139
# Epoch 18/20
# 291/334 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9931 - loss: 0.0185
# Epoch 18: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.9932 - loss: 0.0187 - val_accuracy: 0.7234 - val_loss: 1.9908
# Epoch 19/20
# 295/334 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.9963 - loss: 0.0142
# Epoch 19: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.9962 - loss: 0.0148 - val_accuracy: 0.7485 - val_loss: 1.9737
# Epoch 20/20
# 280/334 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.9973 - loss: 0.0100
# Epoch 20: val_loss did not improve from 1.80979
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9972 - loss: 0.0103 - val_accuracy: 0.7629 - val_loss: 1.8677

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights(checkpoint_VGG16_filepath)

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# Test the model
test_predictions = VGG16_model.predict(test_VGG16, batch_size=20)
test_accuracy = 100 * np.mean(
    np.argmax(test_predictions, axis=1) == np.argmax(test_targets, axis=1)
)
print("Test accuracy: %.4f%%" % test_accuracy)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step
# Test accuracy: 73.0861%

# %% [markdown]
# #### Results
#
# | Model | Test accuracy |
# | ----- | ------------- |
# | CNN   | 1.3221%       |
# | VGG16 | 73.0861%      |

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
def extract_VGG16a(tensor):
    return tf.keras.applications.vgg16.VGG16(
        weights="imagenet", include_top=False
    ).predict(tf.keras.applications.vgg16.preprocess_input(tensor))


def VGG16_predict_breed(img_path):
    """
    Predicts the dog breed from an image using a pre-trained VGG16 model.

    This function extracts bottleneck features from the input image using a 
    pre-trained VGG16 model, then uses these features to predict the dog breed.

    Args:
        img_path (str): Path to the image file.

    Returns:
        str: The predicted dog breed from the model.
    """
    # extract bottleneck features
    bottleneck_feature = extract_VGG16a(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %%
test_file_vgg16 = test_files[3]

vgg16_breed = VGG16_predict_breed(test_file_vgg16)

img = cv2.imread(test_file_vgg16) 
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5, 3))
plt.imshow(cv_rgb)
plt.title(f'The Breed of this dog is: {vgg16_breed.split(".", 1)[1]}')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.

bottleneck_features_Xception = np.load('../data/bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features_Xception['train']
valid_Xception = bottleneck_features_Xception['valid']
test_Xception = bottleneck_features_Xception['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# Brief description of each architecture:
#
# - `VGG19`: Deep architecture with 19 convolution layers. It uses 3x3 filters and is easy to understand and implement. However, it has many parameters, which makes it slower and computationally expensive.
#
# - `Resnet50`: It introduces residual connections (skip connections), which allows training very deep networks without the gradient vanishing problem. It is efficient in terms of performance and achieves high accuracy in classification tasks.
#
# - `InceptionV3`: It uses "Inception" blocks, which apply convolutions of different filter sizes in parallel, capturing multiple feature scales. This makes it very efficient in terms of parameters and generalization ability.
#
# - `Xception`: Based on the concept of Inception, but replaces standard convolutions with depthwise separable convolutions. This reduces the number of parameters while maintaining high accuracy.
#
# For image classification, as in the case of dog breed classification, several important aspects must be considered, such as network capacity, training speed, and the use of transfer learning to improve performance.
#
# Out of the 4 architectures, `Xception` is selected for dog breed classification using transfer learning. It is a reliable, efficient and widely used architecture for transfer learning in image classification tasks due to its ability to learn deep features without overfitting.
#
# - I use `GlobalAveragePooling2D() `to reduce the dimensionality of the extracted features without adding many additional dense layers. This also helps reduce overfitting and simplifies the model, improving generalization.
# - After the pooling layer, we add a `Dense()` layer with 1024 neurons and a `ReLU` activation function. This allows the model to learn more complex combinations of features.
# - The last layer will be a `Dense()` layer with a `softmax` activation function to classify among the 133 dog breeds. The number of neurons in this layer corresponds to the number of classes (breeds) we want to predict.

# %%
### TODO: Define your architecture.

Xception_model = tf.keras.models.Sequential()
Xception_model.add(
    tf.keras.layers.GlobalAveragePooling2D(input_shape=train_Xception.shape[1:])
)
Xception_model.add(tf.keras.layers.Dense(1024, activation='relu'))
Xception_model.add(tf.keras.layers.Dense(133, activation="softmax"))

Xception_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 133)            │       136,325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,234,501 (8.52 MB)
#  Trainable params: 2,234,501 (8.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Xception_model.compile(
    loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"]
)

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpoint_Xception_filepath = "../saved_models/checkpoint.model.Xception.keras"
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_Xception_filepath, verbose=1, save_best_only=True
)

Xception_model.fit(
    train_Xception,
    train_targets,
    validation_data=(valid_Xception, valid_targets),
    epochs=50,
    batch_size=30,
    callbacks=[checkpointer],
    verbose=2,
)
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.63789, saving model to ../saved_models/checkpoint.model.Xception.keras
# 223/223 - 2s - 10ms/step - accuracy: 0.6997 - loss: 1.1661 - val_accuracy: 0.8012 - val_loss: 0.6379
# Epoch 2/50
#
# Epoch 2: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.8469 - loss: 0.4807 - val_accuracy: 0.8096 - val_loss: 0.6431
# Epoch 3/50
#
# Epoch 3: val_loss did not improve from 0.63789
# 223/223 - 1s - 6ms/step - accuracy: 0.8952 - loss: 0.3263 - val_accuracy: 0.8180 - val_loss: 0.7022
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.63789
# 223/223 - 1s - 6ms/step - accuracy: 0.9244 - loss: 0.2365 - val_accuracy: 0.8024 - val_loss: 0.7724
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9382 - loss: 0.1778 - val_accuracy: 0.8359 - val_loss: 0.6722
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9576 - loss: 0.1322 - val_accuracy: 0.8467 - val_loss: 0.6847
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9684 - loss: 0.0922 - val_accuracy: 0.8251 - val_loss: 0.8114
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9719 - loss: 0.0842 - val_accuracy: 0.8335 - val_loss: 0.8124
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9826 - loss: 0.0575 - val_accuracy: 0.8335 - val_loss: 0.7846
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.63789
# 223/223 - 1s - 6ms/step - accuracy: 0.9865 - loss: 0.0476 - val_accuracy: 0.8455 - val_loss: 0.7530
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.63789
# 223/223 - 1s - 6ms/step - accuracy: 0.9907 - loss: 0.0309 - val_accuracy: 0.8287 - val_loss: 0.9111
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9882 - loss: 0.0339 - val_accuracy: 0.8443 - val_loss: 0.7931
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9924 - loss: 0.0271 - val_accuracy: 0.8491 - val_loss: 0.7793
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9946 - loss: 0.0214 - val_accuracy: 0.8491 - val_loss: 0.7918
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9945 - loss: 0.0217 - val_accuracy: 0.8431 - val_loss: 0.8310
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9958 - loss: 0.0210 - val_accuracy: 0.8467 - val_loss: 0.8003
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9966 - loss: 0.0146 - val_accuracy: 0.8443 - val_loss: 0.7744
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9961 - loss: 0.0138 - val_accuracy: 0.8455 - val_loss: 0.8093
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9979 - loss: 0.0096 - val_accuracy: 0.8467 - val_loss: 0.8365
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.8491 - val_loss: 0.8661
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9973 - loss: 0.0120 - val_accuracy: 0.8563 - val_loss: 0.8462
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9975 - loss: 0.0129 - val_accuracy: 0.8539 - val_loss: 0.7954
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9985 - loss: 0.0071 - val_accuracy: 0.8515 - val_loss: 0.8388
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9976 - loss: 0.0124 - val_accuracy: 0.8515 - val_loss: 0.8018
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9979 - loss: 0.0097 - val_accuracy: 0.8551 - val_loss: 0.8380
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9975 - loss: 0.0122 - val_accuracy: 0.8515 - val_loss: 0.8348
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9982 - loss: 0.0089 - val_accuracy: 0.8539 - val_loss: 0.8131
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9982 - loss: 0.0108 - val_accuracy: 0.8503 - val_loss: 0.8329
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9973 - loss: 0.0115 - val_accuracy: 0.8455 - val_loss: 0.8646
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9976 - loss: 0.0100 - val_accuracy: 0.8563 - val_loss: 0.8469
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9975 - loss: 0.0102 - val_accuracy: 0.8431 - val_loss: 0.8518
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9978 - loss: 0.0108 - val_accuracy: 0.8503 - val_loss: 0.8887
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9981 - loss: 0.0094 - val_accuracy: 0.8479 - val_loss: 0.8413
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9978 - loss: 0.0097 - val_accuracy: 0.8503 - val_loss: 0.8399
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9982 - loss: 0.0097 - val_accuracy: 0.8515 - val_loss: 0.8514
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9985 - loss: 0.0080 - val_accuracy: 0.8527 - val_loss: 0.8576
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9987 - loss: 0.0089 - val_accuracy: 0.8467 - val_loss: 0.8630
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9984 - loss: 0.0082 - val_accuracy: 0.8515 - val_loss: 0.8696
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9982 - loss: 0.0093 - val_accuracy: 0.8539 - val_loss: 0.9039
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9984 - loss: 0.0101 - val_accuracy: 0.8503 - val_loss: 0.8932
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9976 - loss: 0.0088 - val_accuracy: 0.8443 - val_loss: 0.8653
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9981 - loss: 0.0114 - val_accuracy: 0.8443 - val_loss: 0.8750
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.8419 - val_loss: 0.8635
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.63789
# 223/223 - 1s - 7ms/step - accuracy: 0.9979 - loss: 0.0094 - val_accuracy: 0.8515 - val_loss: 0.8435
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9985 - loss: 0.0065 - val_accuracy: 0.8491 - val_loss: 0.8801
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9982 - loss: 0.0086 - val_accuracy: 0.8467 - val_loss: 0.8671
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9985 - loss: 0.0062 - val_accuracy: 0.8491 - val_loss: 0.8726
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.8431 - val_loss: 0.8764
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9987 - loss: 0.0072 - val_accuracy: 0.8443 - val_loss: 0.8826
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.63789
# 223/223 - 2s - 7ms/step - accuracy: 0.9982 - loss: 0.0074 - val_accuracy: 0.8527 - val_loss: 0.8804

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Xception_model.load_weights(checkpoint_Xception_filepath)

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
test_predictions = Xception_model.predict(test_Xception, batch_size=20)
test_accuracy = 100 * np.mean(
    np.argmax(test_predictions, axis=1) == np.argmax(test_targets, axis=1)
)
print("Test accuracy: %.4f%%" % test_accuracy)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test accuracy: 79.0670%

# %% [markdown]
# #### Results
#
# | Model | Test accuracy |
# | ----- | ------------- |
# | CNN   | 1.0817%       |
# | VGG16 | 73.0861%      |
# | Xception | 79.0670%      |

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

def extract_Xception(tensor):
    return tf.keras.applications.xception.Xception(
        weights="imagenet", include_top=False
    ).predict(tf.keras.applications.xception.preprocess_input(tensor))


def Xception_predict_breed(img_path):
    """
    Predicts the dog breed from an image using a pre-trained Xception model.

    This function extracts bottleneck features from the input image using a 
    pre-trained Xception model, then uses these features to predict 
    the dog breed.

    Args:
        img_path (str): Path to the image file.

    Returns:
        str: The predicted dog breed from the model.
    """
    # extract bottleneck features
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Xception_model.predict(bottleneck_feature, verbose=0)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# A sample image and output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](../images/sample_human_2.png)
#
# This photo looks like an Afghan Hound.
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def predict_breed(img_path):
    """
    Predicts whether the image is a dog, human, or neither, and predicts the 
    corresponding dog breed if applicable.

    This function first displays the image, then checks if the image contains 
    a dog or a human face. If it's a dog, it predicts the dog's breed. If it's 
    a human, it suggests what dog breed the person might resemble. If neither 
    a dog nor a human is detected, it returns a message indicating that.

    Args:
        img_path (str): Path to the image file.

    Returns:
        None: Outputs a message indicating the detection result and predicted 
        dog breed.
    """
    predict_img = Xception_predict_breed(img_path)
    
    if dog_detector(img_path):
        title = f"This is a Dog with a chance of being of the breed: {predict_img.split(".", 1)[1]}."
        return title
        
    if face_detector(img_path):
        title = f'This is a Human, but it could be a dog breed: {predict_img.split(".", 1)[1]}.'
        return title
    
    else:
        title = 'This is neither dog nor human.'
        return title

    
def display_img(img_path, title):
    """
    Displays an image from the provided path using OpenCV and Matplotlib.

    This function reads the image from the given file path, converts it to RGB 
    format (since OpenCV loads images in BGR format), and then displays it 
    using Matplotlib with the axis turned off.

    Args:
        img_path (str): Path to the image file.
    """
    img = cv2.imread(img_path) 
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(5, 3))
    plt.imshow(cv_rgb)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
display_img(test_files[3], predict_breed(test_files[3]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step

# %%
display_img(human_files_short[1], predict_breed(human_files_short[1]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
#
# _In this project, we tested three different models: a basic CNN, and transfer learning with VGG16 and Xception. The results showed improvements in accuracy, as seen in the summary results table. Xception provided the best performance, improving upon VGG16, which already delivered strong results. Ultimately, we selected Xception as our top-performing model, and it performed well even on challenging images, such as a pencil sketch of a dog._
#
# _Some potential ways to improve the classification could include:_
#
# _1. Increasing the variety of dog images in the training set, capturing different situations, breeds, and angles, or using data augmentation techniques to artificially expand the dataset._
#
# _2. Exploring other transfer learning models, such as ResNet50 or InceptionV3, which may provide better accuracy or generalization capabilities._
# _3. Increasing the depth or complexity of the current model, either by fine-tuning more layers or by modifying the architecture to better capture the intricate features of each dog breed._
#
# _In conclusion, while the model exceeded my expectations with its strong ability to generalize across various types of dog images, including more complex cases like sketches, there is still room for improvement. By adding more training data, testing alternative architectures, or fine-tuning hyperparameters further, we could achieve even higher accuracy and robustness. Additionally, implementing an ensemble of models could further boost performance by leveraging the strengths of multiple architectures._

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

# %%
sample_files = np.array(glob("../data/test-images/*"))
random_files = np.random.choice(sample_files, 6, replace=False)

for sample in random_files:
    display_img(sample, predict_breed(sample))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
