# %% [markdown]
# # Data Scientist Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
#
# This notebook walks you through one of the most popular Udacity projects across machine learning and artificial intellegence nanodegree programs.  The goal is to classify images of dogs according to their breed.
#
# If you are looking for a more guided capstone project related to deep learning and convolutional neural networks, this might be just it.  Notice that even if you follow the notebook to creating your classifier, you must still create a blog post or deploy an application to fulfill the requirements of the capstone project.
#
# Also notice, you may be able to use only parts of this notebook (for example certain coding portions or the data) without completing all parts and still meet all requirements of the capstone project.
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](../images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
import random
import warnings
from glob import glob

import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from PIL import ImageFile
from sklearn.datasets import load_files
from tqdm import tqdm

from extract_bottleneck_features import *

warnings.filterwarnings('ignore')


random.seed(8675309)

# %%
# Define function to load train, test, and validation datasets
def load_dataset(path):
    """
    Load and process the dataset from the specified directory.

    Args:
        path (str): The path to the dataset directory.

    Returns:
        dog_files (list): A list of file paths for each image in the dataset.
        dog_targets (numpy.ndarray): One-hot encoded labels for each image, 
                                     representing 133 possible categories.
    """
    data = load_files(path)
    dog_files = data['filenames']
    dog_targets = tf.keras.utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# %%
# Load train, test, and validation datasets
train_files, train_targets = load_dataset('../data/dog_images/train')
valid_files, valid_targets = load_dataset('../data/dog_images/valid')
test_files, test_targets = load_dataset('../data/dog_images/test')

# Load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("../data/dog_images/train/*/"))]

# Print statistics about the dataset
print(f'There are {len(dog_names)} total dog categories.')
print(f'There are {len(train_files) + len(valid_files) + len(test_files)} total dog images.')
print(f'There are {len(train_files)} training dog images.')
print(f'There are {len(valid_files)} validation dog images.')
print(f'There are {len(test_files)} test dog images.')
# Out:
# There are 133 total dog categories.
# There are 8351 total dog images.
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
# Load filenames in shuffled human dataset
human_files = np.array(glob("../data/lfw/*/*"))
random.shuffle(human_files)

# Print statistics about the human dataset
print(f'There are {len(human_files)} total human images.')
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier(
    '../data/haarcascades/haarcascade_frontalface_alt.xml'
    )

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    """
    Detect if a human face is present in the given image.

    Args:
        img_path (str): The file path to the image.

    Returns:
        bool: True if one or more faces are detected, False otherwise.
    """
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.

def get_percentage_face_detector(files, name):
    """
    Calculate and print the percentage of images containing a human face.

    Args:
        files (list): A list of file paths to the images.
        name (str): A label indicating the name of files being evaluated.

    Returns:
        None
    """
    count = 0
    for image in tqdm(files):
        if face_detector(image):
            count += 1
    print(f'-> {count}% images of the first {len(files)} {name} files were'
          f' detected as human face.')


get_percentage_face_detector(human_files_short, 'human_files_short')
get_percentage_face_detector(dog_files_short, 'dog_files_short')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 164.33it/s]
# -> 100% images of the first 100 human_files_short files were detected as human face.
# 100%|██████████| 100/100 [00:02<00:00, 41.49it/s]
# -> 12% images of the first 100 dog_files_short files were detected as human face.

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# --*
# __Answer:__
#
# _In my opinion, requiring users to provide an image with a clearly visible face is reasonable to some extent, given the algorithm we currently use. This algorithm has both advantages and disadvantages that can be communicated to users. On the positive side, it’s relatively simple, easy to implement, computationally inexpensive, and yields optimal results in many cases. However, there are limitations—it may not work 100% of the time, especially in situations where the face is obscured or partially visible._
#
# _As an alternative to overcome this limitation, we could consider using more robust algorithms, such as Convolutional Neural Networks (CNNs). These models have the potential to detect human faces even in more complex scenarios, as they can be trained on a wide range of features and situations, making them more resilient and accurate at face detection across different conditions. While more computationally expensive, this approach could significantly improve the detection rate in cases where faces are not perfectly presented._
#
# *--
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
# define ResNet50 model
ResNet50_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb\_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb\_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
def path_to_tensor(img_path):
    """
    Convert an image file into a normalized 4D tensor.

    This function loads an image from the given file path, resizes it to the 
    target size of (224, 224), converts the image to a tensor format, and 
    normalizes it. The resulting tensor is expanded into a 4D array (batch size, 
    height, width, channels). If the image file is corrupted or unreadable, a 
    warning message is printed, and None is returned.

    Args:
        img_path (str): The file path to the image.

    Returns:
        np.ndarray or None: The 4D tensor representing the image, or None if the 
        image is corrupted or unreadable.
    """
    try:
        img = tf.keras.preprocessing.image.load_img(img_path, 
                                                    target_size=(224, 224))
        x = tf.keras.preprocessing.image.img_to_array(img)
        # Normalize the image tensor
        return np.expand_dims(x, axis=0)
    except IOError:
        print(f"Warning: Skipping corrupted image {img_path}")
        return None
    
def paths_to_tensor(img_paths):
    """
    Convert a list of image file paths into a 4D tensor.

    This function takes a list of image paths, converts each image into a tensor 
    using `path_to_tensor`, and appends it to a batch of tensors. If an image 
    is corrupted or unreadable, it is skipped. The final output is a 4D tensor 
    containing all the image tensors in the batch.

    Args:
        img_paths (list): A list of file paths to the images.

    Returns:
        np.ndarray: A 4D array containing all the image tensors in the batch.
    """
    batch_tensors = []
    for img_path in img_paths:
        tensor = path_to_tensor(img_path)
        if tensor is not None:
            batch_tensors.append(tensor[0])
    return np.array(batch_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
def ResNet50_predict_labels(img_path):
    """
    Predict the label of an image using the pre-trained ResNet50 model.

    This function processes an image located at `img_path` using ResNet50's 
    preprocessing function, converts it to a tensor, and returns the predicted 
    label as the index of the highest value in the prediction vector.

    Args:
        img_path (str): The file path to the image.

    Returns:
        int: The index of the predicted label.
    """
    img = tf.keras.applications.resnet50.preprocess_input(
            path_to_tensor(img_path)
        )
    return np.argmax(ResNet50_model.predict(img, verbose=0))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    """
    Determine whether a dog is detected in an image.

    This function uses the ResNet50 model to predict labels for the image. 
    If the prediction falls within the range of dog breed labels (151 to 268), 
    the function returns True, indicating a dog has been detected. Otherwise, 
    it returns False.

    Args:
        img_path (str): The file path to the image.

    Returns:
        bool: True if a dog is detected, False otherwise.
    """
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

def get_percentage_dog_detector(files, name):
    """
    Calculate and print the percentage of images containing a dog face.

    Args:
        files (list): A list of file paths to the images.
        name (str): A label indicating the name of files being evaluated.

    Returns:
        None
    """
    count = 0
    for image in tqdm(files):
        if dog_detector(image):
            count += 1
    print(f'-> {count}% images of the first {len(files)} {name} files were'
          f' detected as dog.')


get_percentage_dog_detector(human_files_short, 'human_files_short')
get_percentage_dog_detector(dog_files_short, 'dog_files_short')
# Out:
# 100%|██████████| 100/100 [00:08<00:00, 11.37it/s]
# -> 0% images of the first 100 human_files_short files were detected as dog.
# 100%|██████████| 100/100 [00:08<00:00, 12.42it/s]
# -> 100% images of the first 100 dog_files_short files were detected as dog.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# | Brittany | Welsh Springer Spaniel |
# |- | - |
# |<img src="../images/Brittany_02625.jpg" width="100"> | <img src="../images/Welsh_springer_spaniel_08203.jpg" width="200"> |
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# |Curly-Coated Retriever | American Water Spaniel|
# |- | - |
# |<img src="../images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="../images/American_water_spaniel_00648.jpg" width="200">|
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# |Yellow Labrador | Chocolate Labrador | Black Labrador|
# |- | - | - |
# |<img src="../images/Labrador_retriever_06457.jpg" width="150"> | <img src="../images/Labrador_retriever_06455.jpg" width="240"> | <img src="../images/Labrador_retriever_06449.jpg" width="220">|
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
# Allow loading of truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True


def image_generator(files, targets, batch_size):
    """
    Generator function to yield batches of image data and their corresponding
    labels.

    This function randomly selects a batch of file paths, converts the images
    to tensors, and yields the batch of images along with their corresponding
    labels. It runs in an infinite loop, useful for training models in Keras.

    Args:
        files (np.ndarray): Array of file paths to the images.
        targets (np.ndarray): Array of corresponding labels for the images.
        batch_size (int): The size of each batch of images and labels.

    Yields:
        tuple: A tuple containing:
            - np.ndarray: Batch of image tensors.
            - np.ndarray: Batch of corresponding labels.
    """
    while True:
        batch_paths = np.random.choice(a=files, size=batch_size)
        batch_input = paths_to_tensor(batch_paths)
        valid_paths = [p for p in batch_paths if path_to_tensor(p) is not None]
        batch_indices = [
            np.where(files == img_path)[0][0] for img_path in valid_paths
        ]
        batch_output = np.array([targets[index] for index in batch_indices])

        if len(batch_input) > 0:  # Ensure there is data to yield
            yield batch_input, batch_output


# Create generators for train, validation, and test datasets
train_generator = image_generator(train_files, train_targets, batch_size=64)
valid_generator = image_generator(valid_files, valid_targets, batch_size=64)
test_generator = image_generator(test_files, test_targets, batch_size=64)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](../images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
### TODO: Define your architecture.
# building a linear stack of layers with the sequential model

input_shape = (224, 224, 3)
model = tf.keras.models.Sequential()

model.add(tf.keras.Input(shape=input_shape))

# Add the input layer and hidden layer 1
model.add(
    tf.keras.layers.Conv2D(
        32,
        kernel_size=(3, 3),
        activation="relu",
    )
)

# Add the input layer and hidden layer 2
model.add(tf.keras.layers.Conv2D(64, (3, 3), activation="relu"))

# Flatten convolutional output
model.add(tf.keras.layers.Flatten())

# Add the input layer and hidden layer 3
model.add(tf.keras.layers.Dense(128, activation="relu"))

# Add the output layer
model.add(tf.keras.layers.Dense(133, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 220, 220, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3097600)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │   396,492,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 133)            │        17,157 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 396,529,477 (1.48 GB)
#  Trainable params: 396,529,477 (1.48 GB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the Model

# %%
# Set a smaller learning rate
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer=adam, loss="categorical_crossentropy", metrics=["accuracy"]
)

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: specify the number of epochs that you would like to use
#  to train the model.

epochs = 1

### Do NOT modify the code below this line.

# Add checkpoint to save the best model
checkpoint_cnn_filepath = "../saved_models/checkpoint.model.cnn.keras"
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_cnn_filepath, verbose=1, save_best_only=True
)

# ReduceLROnPlateau: This callback reduces the learning rate when a metric 
# has stopped improving.
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", factor=0.1, patience=5
)

# Train the model
model.fit(
    train_generator,
    steps_per_epoch=len(train_files) // 32,
    validation_data=valid_generator,
    validation_steps=len(valid_files) // 32,
    epochs=epochs,
    callbacks=[checkpointer, reduce_lr],
    verbose=1,
)
# Out:
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.1775 - loss: 629.2650
# Epoch 1: val_loss improved from inf to 5.18557, saving model to ../saved_models/checkpoint.model.cnn.keras
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 960s 5s/step - accuracy: 0.1782 - loss: 626.8559 - val_accuracy: 0.0150 - val_loss: 5.1856 - learning_rate: 0.0010

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights(checkpoint_cnn_filepath)

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# Evaluate the model on the test data using `evaluate_generator`
test_loss, test_accuracy = model.evaluate(
    test_generator, steps=len(test_files) // 32
)

# Convert the accuracy to percentage
test_accuracy = test_accuracy * 100

print("Test accuracy: %.4f%%" % test_accuracy)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 16s 602ms/step - accuracy: 0.0197 - loss: 5.1594
# Test accuracy: 1.6827%

# %% [markdown]
# #### Results
#
# | Model | Test accuracy |
# | -|-|
# | CNN |1.6827%|

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features_VGG16 = np.load('../data/bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features_VGG16['train']
valid_VGG16 = bottleneck_features_VGG16['valid']
test_VGG16 = bottleneck_features_VGG16['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = tf.keras.models.Sequential()
VGG16_model.add(
    tf.keras.layers.GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:])
)
VGG16_model.add(tf.keras.layers.Dense(133, activation="softmax"))

VGG16_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 133)            │        68,229 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,229 (266.52 KB)
#  Trainable params: 68,229 (266.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(
    loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"]
)

# %% [markdown]
# ### Train the Model

# %%
checkpoint_VGG16_filepath = "../saved_models/checkpoint.model.VGG16.keras"
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_VGG16_filepath, verbose=1, save_best_only=True
)

VGG16_model.fit(
    train_VGG16,
    train_targets,
    validation_data=(valid_VGG16, valid_targets),
    epochs=20,
    batch_size=20,
    callbacks=[checkpointer],
    verbose=1,
)
# Out:
# Epoch 1/20
# 295/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0980 - loss: 12.4055
# Epoch 1: val_loss improved from inf to 3.52189, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1120 - loss: 11.8649 - val_accuracy: 0.4647 - val_loss: 3.5219
# Epoch 2/20
# 315/334 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.5812 - loss: 2.3130
# Epoch 2: val_loss improved from 3.52189 to 2.51910, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5828 - loss: 2.3030 - val_accuracy: 0.5760 - val_loss: 2.5191
# Epoch 3/20
# 289/334 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.7409 - loss: 1.2433
# Epoch 3: val_loss improved from 2.51910 to 2.06664, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7409 - loss: 1.2440 - val_accuracy: 0.6539 - val_loss: 2.0666
# Epoch 4/20
# 333/334 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.8168 - loss: 0.7836
# Epoch 4: val_loss improved from 2.06664 to 2.02244, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8167 - loss: 0.7837 - val_accuracy: 0.6623 - val_loss: 2.0224
# Epoch 5/20
# 332/334 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.8626 - loss: 0.5493
# Epoch 5: val_loss improved from 2.02244 to 1.81731, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8626 - loss: 0.5494 - val_accuracy: 0.6922 - val_loss: 1.8173
# Epoch 6/20
# 320/334 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.9019 - loss: 0.3748
# Epoch 6: val_loss did not improve from 1.81731
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9016 - loss: 0.3763 - val_accuracy: 0.6874 - val_loss: 1.9066
# Epoch 7/20
# 286/334 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9243 - loss: 0.2657
# Epoch 7: val_loss improved from 1.81731 to 1.79416, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9236 - loss: 0.2705 - val_accuracy: 0.7114 - val_loss: 1.7942
# Epoch 8/20
# 283/334 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.9430 - loss: 0.2084
# Epoch 8: val_loss improved from 1.79416 to 1.74544, saving model to ../saved_models/checkpoint.model.VGG16.keras
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9423 - loss: 0.2099 - val_accuracy: 0.7174 - val_loss: 1.7454
# Epoch 9/20
# 318/334 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9600 - loss: 0.1374
# Epoch 9: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9597 - loss: 0.1390 - val_accuracy: 0.7066 - val_loss: 1.9165
# Epoch 10/20
# 326/334 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9649 - loss: 0.1244
# Epoch 10: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9649 - loss: 0.1245 - val_accuracy: 0.7090 - val_loss: 1.9107
# Epoch 11/20
# 317/334 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.9736 - loss: 0.1061
# Epoch 11: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9734 - loss: 0.1061 - val_accuracy: 0.7269 - val_loss: 1.8749
# Epoch 12/20
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9812 - loss: 0.0682
# Epoch 12: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9812 - loss: 0.0682 - val_accuracy: 0.7317 - val_loss: 2.0165
# Epoch 13/20
# 333/334 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.9846 - loss: 0.0477
# Epoch 13: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9845 - loss: 0.0478 - val_accuracy: 0.7174 - val_loss: 1.9157
# Epoch 14/20
# 293/334 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.9871 - loss: 0.0360
# Epoch 14: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9871 - loss: 0.0368 - val_accuracy: 0.7078 - val_loss: 1.9372
# Epoch 15/20
# 324/334 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9893 - loss: 0.0418
# Epoch 15: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9892 - loss: 0.0418 - val_accuracy: 0.7533 - val_loss: 1.8648
# Epoch 16/20
# 299/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.0254
# Epoch 16: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9927 - loss: 0.0263 - val_accuracy: 0.7341 - val_loss: 1.9242
# Epoch 17/20
# 327/334 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9928 - loss: 0.0296
# Epoch 17: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9928 - loss: 0.0296 - val_accuracy: 0.7413 - val_loss: 1.9009
# Epoch 18/20
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9960 - loss: 0.0164
# Epoch 18: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9960 - loss: 0.0165 - val_accuracy: 0.7305 - val_loss: 2.0351
# Epoch 19/20
# 310/334 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.9932 - loss: 0.0165
# Epoch 19: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9933 - loss: 0.0165 - val_accuracy: 0.7473 - val_loss: 1.8980
# Epoch 20/20
# 325/334 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9962 - loss: 0.0114
# Epoch 20: val_loss did not improve from 1.74544
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.7377 - val_loss: 1.9466

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights(checkpoint_VGG16_filepath)

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# Test the model
test_predictions = VGG16_model.predict(test_VGG16, batch_size=20)
test_accuracy = 100 * np.mean(
    np.argmax(test_predictions, axis=1) == np.argmax(test_targets, axis=1)
)
print("Test accuracy: %.4f%%" % test_accuracy)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step
# Test accuracy: 71.8900%

# %% [markdown]
# #### Results
#
# | Model | Test accuracy |
# | ----- | ------------- |
# | CNN   | 1.6827%       |
# | VGG16 | 71.8900%      |

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
def extract_VGG16a(tensor):
    return tf.keras.applications.vgg16.VGG16(
        weights="imagenet", include_top=False
    ).predict(tf.keras.applications.vgg16.preprocess_input(tensor))


def VGG16_predict_breed(img_path):
    """
    Predicts the dog breed from an image using a pre-trained VGG16 model.

    This function extracts bottleneck features from the input image using a 
    pre-trained VGG16 model, then uses these features to predict the dog breed.

    Args:
        img_path (str): Path to the image file.

    Returns:
        str: The predicted dog breed from the model.
    """
    # extract bottleneck features
    bottleneck_feature = extract_VGG16a(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %%
test_file_vgg16 = test_files[3]

img = cv2.imread(test_file_vgg16) 
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5, 3))
plt.imshow(cv_rgb)
plt.axis('off')
plt.show()

vgg16_breed = VGG16_predict_breed(test_file_vgg16)
print(f'The Breed of this dog is {vgg16_breed}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# The Breed of this dog is rain/019.Bedlington_terrier

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.

bottleneck_features_Xception = np.load('../data/bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features_Xception['train']
valid_Xception = bottleneck_features_Xception['valid']
test_Xception = bottleneck_features_Xception['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# Brief description of each architecture:
#
# - `VGG19`: Deep architecture with 19 convolution layers. It uses 3x3 filters and is easy to understand and implement. However, it has many parameters, which makes it slower and computationally expensive.
#
# - `Resnet50`: It introduces residual connections (skip connections), which allows training very deep networks without the gradient vanishing problem. It is efficient in terms of performance and achieves high accuracy in classification tasks.
#
# - `InceptionV3`: It uses "Inception" blocks, which apply convolutions of different filter sizes in parallel, capturing multiple feature scales. This makes it very efficient in terms of parameters and generalization ability.
#
# - `Xception`: Based on the concept of Inception, but replaces standard convolutions with depthwise separable convolutions. This reduces the number of parameters while maintaining high accuracy.
#
# For image classification, as in the case of dog breed classification, several important aspects must be considered, such as network capacity, training speed, and the use of transfer learning to improve performance.
#
# Out of the 4 architectures, `Xception` is selected for dog breed classification using transfer learning. It is a reliable, efficient and widely used architecture for transfer learning in image classification tasks due to its ability to learn deep features without overfitting.
#
# - I use `GlobalAveragePooling2D() `to reduce the dimensionality of the extracted features without adding many additional dense layers. This also helps reduce overfitting and simplifies the model, improving generalization.
# - After the pooling layer, we add a `Dense()` layer with 1024 neurons and a `ReLU` activation function. This allows the model to learn more complex combinations of features.
# - The last layer will be a `Dense()` layer with a `softmax` activation function to classify among the 133 dog breeds. The number of neurons in this layer corresponds to the number of classes (breeds) we want to predict.

# %%
### TODO: Define your architecture.

Xception_model = tf.keras.models.Sequential()
Xception_model.add(
    tf.keras.layers.GlobalAveragePooling2D(input_shape=train_Xception.shape[1:])
)
Xception_model.add(tf.keras.layers.Dense(1024, activation='relu'))
Xception_model.add(tf.keras.layers.Dense(133, activation="softmax"))

Xception_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 133)            │       136,325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,234,501 (8.52 MB)
#  Trainable params: 2,234,501 (8.52 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Xception_model.compile(
    loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"]
)

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpoint_Xception_filepath = "../saved_models/checkpoint.model.Xception.keras"
checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_Xception_filepath, verbose=1, save_best_only=True
)

Xception_model.fit(
    train_Xception,
    train_targets,
    validation_data=(valid_Xception, valid_targets),
    epochs=50,
    batch_size=30,
    callbacks=[checkpointer],
    verbose=2,
)
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.71689, saving model to ../saved_models/checkpoint.model.Xception.keras
# 223/223 - 3s - 12ms/step - accuracy: 0.7000 - loss: 1.1510 - val_accuracy: 0.7856 - val_loss: 0.7169
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.71689 to 0.71010, saving model to ../saved_models/checkpoint.model.Xception.keras
# 223/223 - 2s - 9ms/step - accuracy: 0.8490 - loss: 0.4818 - val_accuracy: 0.7988 - val_loss: 0.7101
# Epoch 3/50
#
# Epoch 3: val_loss improved from 0.71010 to 0.68748, saving model to ../saved_models/checkpoint.model.Xception.keras
# 223/223 - 2s - 9ms/step - accuracy: 0.8907 - loss: 0.3274 - val_accuracy: 0.8060 - val_loss: 0.6875
# Epoch 4/50
#
# Epoch 4: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9228 - loss: 0.2351 - val_accuracy: 0.8060 - val_loss: 0.7477
# Epoch 5/50
#
# Epoch 5: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9398 - loss: 0.1662 - val_accuracy: 0.8120 - val_loss: 0.7870
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.68748
# 223/223 - 2s - 10ms/step - accuracy: 0.9579 - loss: 0.1279 - val_accuracy: 0.8455 - val_loss: 0.7376
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9695 - loss: 0.0989 - val_accuracy: 0.8263 - val_loss: 0.7187
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9749 - loss: 0.0768 - val_accuracy: 0.8503 - val_loss: 0.7097
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9792 - loss: 0.0667 - val_accuracy: 0.8431 - val_loss: 0.7259
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9874 - loss: 0.0429 - val_accuracy: 0.8491 - val_loss: 0.7543
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9891 - loss: 0.0394 - val_accuracy: 0.8467 - val_loss: 0.8225
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9897 - loss: 0.0360 - val_accuracy: 0.8383 - val_loss: 0.8323
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.68748
# 223/223 - 2s - 10ms/step - accuracy: 0.9927 - loss: 0.0267 - val_accuracy: 0.8431 - val_loss: 0.8465
# Epoch 14/50
#
# Epoch 14: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9937 - loss: 0.0249 - val_accuracy: 0.8431 - val_loss: 0.8244
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9949 - loss: 0.0202 - val_accuracy: 0.8491 - val_loss: 0.7393
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.68748
# 223/223 - 2s - 11ms/step - accuracy: 0.9960 - loss: 0.0190 - val_accuracy: 0.8539 - val_loss: 0.7789
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9979 - loss: 0.0089 - val_accuracy: 0.8407 - val_loss: 0.8519
# Epoch 18/50
#
# Epoch 18: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9972 - loss: 0.0128 - val_accuracy: 0.8503 - val_loss: 0.7932
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 0.68748
# 223/223 - 2s - 10ms/step - accuracy: 0.9975 - loss: 0.0105 - val_accuracy: 0.8491 - val_loss: 0.8291
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.8479 - val_loss: 0.8329
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9976 - loss: 0.0144 - val_accuracy: 0.8587 - val_loss: 0.8080
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.68748
# 223/223 - 2s - 9ms/step - accuracy: 0.9976 - loss: 0.0107 - val_accuracy: 0.8503 - val_loss: 0.8449
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9973 - loss: 0.0126 - val_accuracy: 0.8479 - val_loss: 0.8806
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9975 - loss: 0.0126 - val_accuracy: 0.8455 - val_loss: 0.8799
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9979 - loss: 0.0104 - val_accuracy: 0.8443 - val_loss: 0.8253
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9979 - loss: 0.0100 - val_accuracy: 0.8491 - val_loss: 0.8417
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9975 - loss: 0.0085 - val_accuracy: 0.8431 - val_loss: 0.8888
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9978 - loss: 0.0105 - val_accuracy: 0.8551 - val_loss: 0.8491
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9984 - loss: 0.0090 - val_accuracy: 0.8515 - val_loss: 0.8860
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.68748
# 223/223 - 2s - 7ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.8383 - val_loss: 0.9639
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9982 - loss: 0.0090 - val_accuracy: 0.8527 - val_loss: 0.8852
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9982 - loss: 0.0084 - val_accuracy: 0.8503 - val_loss: 0.9159
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9988 - loss: 0.0088 - val_accuracy: 0.8479 - val_loss: 0.8673
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9976 - loss: 0.0115 - val_accuracy: 0.8443 - val_loss: 0.8954
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9975 - loss: 0.0110 - val_accuracy: 0.8515 - val_loss: 0.8724
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9987 - loss: 0.0088 - val_accuracy: 0.8491 - val_loss: 0.8644
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9984 - loss: 0.0087 - val_accuracy: 0.8491 - val_loss: 0.8369
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9987 - loss: 0.0056 - val_accuracy: 0.8467 - val_loss: 0.9101
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9985 - loss: 0.0079 - val_accuracy: 0.8515 - val_loss: 0.8504
# Epoch 40/50
#
# Epoch 40: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.8527 - val_loss: 0.8712
# Epoch 41/50
#
# Epoch 41: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9981 - loss: 0.0101 - val_accuracy: 0.8455 - val_loss: 0.8943
# Epoch 42/50
#
# Epoch 42: val_loss did not improve from 0.68748
# 223/223 - 2s - 7ms/step - accuracy: 0.9982 - loss: 0.0094 - val_accuracy: 0.8491 - val_loss: 0.8633
# Epoch 43/50
#
# Epoch 43: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9985 - loss: 0.0075 - val_accuracy: 0.8515 - val_loss: 0.8495
# Epoch 44/50
#
# Epoch 44: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9988 - loss: 0.0053 - val_accuracy: 0.8503 - val_loss: 0.8288
# Epoch 45/50
#
# Epoch 45: val_loss did not improve from 0.68748
# 223/223 - 2s - 7ms/step - accuracy: 0.9984 - loss: 0.0066 - val_accuracy: 0.8503 - val_loss: 0.8708
# Epoch 46/50
#
# Epoch 46: val_loss did not improve from 0.68748
# 223/223 - 2s - 7ms/step - accuracy: 0.9988 - loss: 0.0072 - val_accuracy: 0.8515 - val_loss: 0.8694
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9987 - loss: 0.0071 - val_accuracy: 0.8491 - val_loss: 0.8552
# Epoch 48/50
#
# Epoch 48: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9984 - loss: 0.0066 - val_accuracy: 0.8515 - val_loss: 0.8994
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9990 - loss: 0.0049 - val_accuracy: 0.8503 - val_loss: 0.8954
# Epoch 50/50
#
# Epoch 50: val_loss did not improve from 0.68748
# 223/223 - 2s - 8ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.8515 - val_loss: 0.8669

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Xception_model.load_weights(checkpoint_Xception_filepath)

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
test_predictions = Xception_model.predict(test_Xception, batch_size=20)
test_accuracy = 100 * np.mean(
    np.argmax(test_predictions, axis=1) == np.argmax(test_targets, axis=1)
)
print("Test accuracy: %.4f%%" % test_accuracy)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test accuracy: 81.6986%

# %% [markdown]
# #### Results
#
# | Model | Test accuracy |
# | ----- | ------------- |
# | CNN   | 1.6827%       |
# | VGG16 | 71.8900%      |
# | Resnet50 | 81.6986%      |

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

def extract_Xception(tensor):
    return tf.keras.applications.xception.Xception(
        weights="imagenet", include_top=False
    ).predict(tf.keras.applications.xception.preprocess_input(tensor))


def Xception_predict_breed(img_path):
    """
    Predicts the dog breed from an image using a pre-trained Xception model.

    This function extracts bottleneck features from the input image using a 
    pre-trained Xception model, then uses these features to predict 
    the dog breed.

    Args:
        img_path (str): Path to the image file.

    Returns:
        str: The predicted dog breed from the model.
    """
    # extract bottleneck features
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Xception_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# A sample image and output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_2.png)
#
# This photo looks like an Afghan Hound.
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def display_img(img_path):
    """
    Displays an image from the provided path using OpenCV and Matplotlib.

    This function reads the image from the given file path, converts it to RGB 
    format (since OpenCV loads images in BGR format), and then displays it 
    using Matplotlib with the axis turned off.

    Args:
        img_path (str): Path to the image file.
    """
    img = cv2.imread(img_path) 
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(5, 3))
    plt.imshow(cv_rgb)
    plt.axis('off')
    plt.show()


def predict_breed(img_path):
    """
    Predicts whether the image is a dog, human, or neither, and predicts the 
    corresponding dog breed if applicable.

    This function first displays the image, then checks if the image contains 
    a dog or a human face. If it's a dog, it predicts the dog's breed. If it's 
    a human, it suggests what dog breed the person might resemble. If neither 
    a dog nor a human is detected, it returns a message indicating that.

    Args:
        img_path (str): Path to the image file.

    Returns:
        None: Outputs a message indicating the detection result and predicted 
        dog breed.
    """
    display_img(img_path)
    
    if dog_detector(img_path):
        return print(f"This is a Dog with a chance of being of the breed: "
                     f"{Xception_predict_breed(img_path)}")
        
    if face_detector(img_path):
        return print(f'This is a Human but you could be a dog breed: '
                     f'{Xception_predict_breed(img_path)}')
    
    else:
        return print(f'This is neither dog nor human.')

# %%
predict_breed(test_files[3])
# Out:
# WARNING:tensorflow:5 out of the last 50 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x3810e5800> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This is a Dog with a chance of being of the breed: rain/019.Bedlington_terrier

# %%
predict_breed(human_files_short[1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# This is a Human but you could be a dog breed: rain/119.Petit_basset_griffon_vendeen

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

# %%
sample_files = np.array(glob("../data/test-images/*"))
random_files = np.random.choice(sample_files, 6, replace=False)

for sample in random_files:
    predict_breed(sample)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# This is a Dog with a chance of being of the breed: rain/123.Pomeranian
# This is neither dog nor human.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# This is a Human but you could be a dog breed: rain/012.Australian_shepherd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# This is a Dog with a chance of being of the breed: rain/117.Pekingese
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# This is a Human but you could be a dog breed: rain/119.Petit_basset_griffon_vendeen
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# This is a Human but you could be a dog breed: rain/119.Petit_basset_griffon_vendeen
